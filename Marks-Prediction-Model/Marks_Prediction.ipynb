# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("B:\swees\Datascience\Project_Folder\Marks_Prediction_Model\marks file.xlsx")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\asus\AppData\Local\Temp\ipykernel_28380\3051461537.py:1: SyntaxWarning: invalid escape sequence '\s'
#   df=pd.read_excel("B:\swees\Datascience\Project_Folder\Marks_Prediction_Model\marks file.xlsx")

# %%
df.head()
# Out:
#    student_id  hours_studied  marks
# 0           1              1     20
# 1           2              2     35
# 2           3              3     50
# 3           4              4     65
# 4           5              5     80

# %%
plt.figure(figsize=(5,6))
plt.scatter(df['hours_studied'],df['marks'])
plt.title("Hours vs marks")
plt.xlabel('hours_studied')
plt.ylabel('marks')
plt.gca().set_facecolor('lightgreen')   # sets the background color of the plot area
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x=df[['hours_studied']]
y=df['marks']

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %%
predicted=model.predict(x_test)

# %%
predicted=model.predict(x_test)

# %%
for hours,mark in zip(x_test['hours_studied'],predicted):
    print(f"Hours studied:{hours} ->Mark Scored:{round(mark)}")
# Out:
# Hours studied:1 ->Mark Scored:23
# Hours studied:2 ->Mark Scored:36

# %%
print(f"Hours studied: 9->Marks scored: {model.predict([[9]])}")
# Out:
# Hours studied: 9->Marks scored: [127.32142857]
# c:\Users\asus\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import joblib

# %%
joblib.dump(model,"model.pkl")
# Out:
# ['model.pkl']
